# %% [markdown]
# # Set Up
#
# 1. click “Edit” -> "Notebook Settings" -> "Hardware accelerator, GPU" -> Save
# <img src="https://z3.ax1x.com/2021/03/30/ciQWWV.png">
#
# 2. Click the folder icon on the left, upload your video file, and copy the uploaded video path
#
# <img src="https://z3.ax1x.com/2021/03/30/cilvhq.png">
#
# 3. Run the code, enter the pasted video path

# %% [markdown]
# check whether GPU works

# %%
# !nvidia-smi
# Out:
# Wed Aug  6 17:07:37 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0

# %% [markdown]
# # Install Dependencies

# %%
# !git clone --depth=1 https://github.com/YaoFANGUK/video-subtitle-extractor.git
# Out:
# fatal: destination path 'video-subtitle-extractor' already exists and is not an empty directory.

# %%
cd video-subtitle-extractor
# Out:
# /content/video-subtitle-extractor

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: opencv-python==4.10.0.84 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (4.10.0.84)
# Requirement already satisfied: Levenshtein==0.26.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (0.26.0)
# Requirement already satisfied: pillow==10.4.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (10.4.0)
# Collecting tqdm==4.66.5 (from -r requirements.txt (line 4))
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: filesplit==3.0.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (3.0.2)
# Requirement already satisfied: pysrt==1.1.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (1.1.2)
# Requirement already satisfied: wordsegment==1.3.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: scikit-image==0.25.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (0.25.1)
# Requirement already satisfied: lmdb==1.5.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (1.5.1)
# Requirement already satisfied: pyclipper==1.3.0.post5 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (1.3.0.post5)
# Requirement already satisfied: PySimpleGUI-4-foss==4.60.4.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (4.60.4.1)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (1.26.4)
# Requirement already satisfied: shapely==2.0.7 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (2.0.7)
# Requirement already satisfied: six==1.17.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 14)) (1.17.0)
# Requirement already satisfied: setuptools==75.8.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 15)) (75.8.0)
# Requirement already satisfied: je-paddleocr==2.9.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (2.9.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /usr/local/lib/python3.11/dist-packages (from Levenshtein==0.26.0->-r requirements.txt (line 2)) (3.13.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/dist-packages (from pysrt==1.1.2->-r requirements.txt (line 6)) (5.2.0)
# Requirement already satisfied: scipy>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from scikit-image==0.25.1->-r requirements.txt (line 8)) (1.16.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image==0.25.1->-r requirements.txt (line 8)) (3.5)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image==0.25.1->-r requirements.txt (line 8)) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image==0.25.1->-r requirements.txt (line 8)) (2025.6.11)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image==0.25.1->-r requirements.txt (line 8)) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image==0.25.1->-r requirements.txt (line 8)) (0.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from je-paddleocr==2.9.1->-r requirements.txt (line 16)) (4.11.0.86)
# Requirement already satisfied: cython in /usr/local/lib/python3.11/dist-packages (from je-paddleocr==2.9.1->-r requirements.txt (line 16)) (3.0.12)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from je-paddleocr==2.9.1->-r requirements.txt (line 16)) (6.0.2)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.11/dist-packages (from je-paddleocr==2.9.1->-r requirements.txt (line 16)) (1.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from je-paddleocr==2.9.1->-r requirements.txt (line 16)) (4.13.4)
# Requirement already satisfied: fonttools>=4.24.0 in /usr/local/lib/python3.11/dist-packages (from je-paddleocr==2.9.1->-r requirements.txt (line 16)) (4.59.0)
# Requirement already satisfied: fire>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from je-paddleocr==2.9.1->-r requirements.txt (line 16)) (0.7.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from je-paddleocr==2.9.1->-r requirements.txt (line 16)) (2.32.3)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.11/dist-packages (from je-paddleocr==2.9.1->-r requirements.txt (line 16)) (2.0.8)
# Requirement already satisfied: albucore in /usr/local/lib/python3.11/dist-packages (from je-paddleocr==2.9.1->-r requirements.txt (line 16)) (0.0.24)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from fire>=0.3.0->je-paddleocr==2.9.1->-r requirements.txt (line 16)) (3.1.0)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore->je-paddleocr==2.9.1->-r requirements.txt (line 16)) (3.12.5)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.11/dist-packages (from albucore->je-paddleocr==2.9.1->-r requirements.txt (line 16)) (6.5.0)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albucore->je-paddleocr==2.9.1->-r requirements.txt (line 16)) (4.11.0.86)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from albumentations->je-paddleocr==2.9.1->-r requirements.txt (line 16)) (2.11.7)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->je-paddleocr==2.9.1->-r requirements.txt (line 16)) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->je-paddleocr==2.9.1->-r requirements.txt (line 16)) (4.14.1)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-docx->je-paddleocr==2.9.1->-r requirements.txt (line 16)) (5.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->je-paddleocr==2.9.1->-r requirements.txt (line 16)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->je-paddleocr==2.9.1->-r requirements.txt (line 16)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->je-paddleocr==2.9.1->-r requirements.txt (line 16)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->je-paddleocr==2.9.1->-r requirements.txt (line 16)) (2025.7.14)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations->je-paddleocr==2.9.1->-r requirements.txt (line 16)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations->je-paddleocr==2.9.1->-r requirements.txt (line 16)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations->je-paddleocr==2.9.1->-r requirements.txt (line 16)) (0.4.1)
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dataproc-spark-connect 0.8.3 requires tqdm>=4.67, but you have tqdm 4.66.5 which is incompatible.
# Successfully installed tqdm-4.66.5

# %%
pip install "jedi>=0.16" "tqdm>=4.67"
# Out:
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (0.19.2)
# Collecting tqdm>=4.67
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16) (0.8.4)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.5
#     Uninstalling tqdm-4.66.5:
#       Successfully uninstalled tqdm-4.66.5
# Successfully installed tqdm-4.67.1

# %%
# !echo -e '[DEFAULT]\nInterface = English\nLanguage = en\nMode = fast' > /content/video-subtitle-extractor/settings.ini

# %%
# !pip install paddlepaddle-gpu==2.6.2 -f https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# Out:
# Looking in links: https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# Requirement already satisfied: paddlepaddle-gpu==2.6.2 in /usr/local/lib/python3.11/dist-packages (2.6.2)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from paddlepaddle-gpu==2.6.2) (0.28.1)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.11/dist-packages (from paddlepaddle-gpu==2.6.2) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from paddlepaddle-gpu==2.6.2) (10.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from paddlepaddle-gpu==2.6.2) (4.4.2)
# Requirement already satisfied: astor in /usr/local/lib/python3.11/dist-packages (from paddlepaddle-gpu==2.6.2) (0.8.1)
# Requirement already satisfied: opt-einsum==3.3.0 in /usr/local/lib/python3.11/dist-packages (from paddlepaddle-gpu==2.6.2) (3.3.0)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from paddlepaddle-gpu==2.6.2) (5.29.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->paddlepaddle-gpu==2.6.2) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx->paddlepaddle-gpu==2.6.2) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->paddlepaddle-gpu==2.6.2) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx->paddlepaddle-gpu==2.6.2) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->paddlepaddle-gpu==2.6.2) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->paddlepaddle-gpu==2.6.2) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->paddlepaddle-gpu==2.6.2) (4.14.1)

# %% [markdown]
# # Run

# %% [markdown]
# Here is an example:
#
# input video path: /content/video-subtitle-extractor/test/test_en.mp4
#
# input subtitle area: 612 717 90 1191

# %%
# !python ./backend/main.py
# Out:
# Traceback (most recent call last):
#   File "/content/video-subtitle-extractor/./backend/main.py", line 27, in <module>
#     from backend.tools.ocr import OcrRecogniser, get_coordinates
# ModuleNotFoundError: No module named 'backend'
